# %% [markdown]
# ## Exercice 1
#
# - Quelle est la probabilité élémentaire 𝑃(𝐴, 𝑆, 𝑉, 𝐶𝑎, 𝐼, non(𝐷̅) , non(𝐶̅))
#
# 𝑃(𝐴, 𝑆, 𝑉, 𝐶𝑎, 𝐼, non(𝐷̅) , non(𝐶̅)) = P(A | V, Ca) * P(𝑆, 𝑉, 𝐶𝑎, 𝐼, non(𝐷̅) , non(𝐶̅))
# = ...
#
#
# - Quelle est la proba conditionnelle de 𝑃(𝐴, 𝑆 | 𝑉, 𝐶𝑎, 𝐼, non(𝐷̅) , non(𝐶̅))
#
# P(X|O) = freq(X, O)/freq(O)
# ..

# %% [markdown]
# ## Exercice 2
#
# - Calculer la probabilité marginale suivante 𝑃(𝑀, 𝐹)
#
# Il manque A donc il faudra faire les probabilité avec A et non(A).
#
# ```
# P(M, F) = P(M, F, A) + P(M, F, non(A))
#         = P(A|M) * P(M|F) * P(F)
#         + P(non(A)|M) * P(M|F) * P(F)
#
# or P(A|M) + P(non(A)|M) = 1
# ```
#
#
#
# A ne sert finalement à rien car les Analyses sont des conséquences de F et M.
#
# Donc P(M, F) = P(M|F) * P(F)

# %% [markdown]
# ## Exercice 3
#
# - Estimez les probabilités des tables correspondant aux quatre nœuds
#
# P(G) = 7/22
# P(non(G)) = 15/22
#
# P(E) = 14/22
# P(non(E)) = 8/22
#
# P(T)=....
#
# - Calculer P(T | G, E)
#
# P(T | G, E) = freq(T, G, E) / freq(G, E)
#
# P(T | G, E) = 1/4
# P(non(T) | G, E) = 3/4
#
# - Calculer P(T | G, non(E))
#
# P(T | G, non(E)) = *freq(T, G, non(E))* / **freq(G, non(E))**
#
# P(T | G, non(E)) = *2*/**3**
#
# P(non(T) | G, non(E)) = *1*/**3**
