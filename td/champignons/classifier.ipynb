# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

data = pd.read_csv('Champignons.csv')

# %%
data.head()
# Out:
#    Unnamed: 0      Classe  Chapeau Surface Chapeau Couleur Chapeau  bruises  \
# 0           0     Toxique  Convexe           Lisse          Marron     True
# 1           1  Comestible  Convexe           Lisse           Jaune     True
# 2           2  Comestible   Cloche           Lisse           Blanc     True
# 3           3     Toxique  Convexe       Ecailleux           Blanc     True
# 4           4  Comestible  Convexe           Lisse            Gris    False
#
#        Odeur Lamelles Espacement des lamelles Taille des lamelles  ...  \
# 0  Pinquante    Libre                  Proche              Etroit  ...
# 1     Amande    Libre                  Proche               Large  ...
# 2       Anis    Libre                  Proche               Large  ...
# 3  Pinquante    Libre                  Proche              Etroit  ...
# 4     Aucune    Libre                 Eloigné               Large  ...
#
#   Surface au dessus de anneau Surface sous anneau Couleur sur anneau  \
# ...
